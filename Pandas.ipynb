# %%
pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 1.8/1.8 MB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3
#     Uninstalling pip-22.3:
#       Successfully uninstalled pip-22.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.shape
# Out:
# (31, 11)

# %%
df.size
# Out:
# 341

# %%
df.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
df["Events"].unique()
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df[df["Events"]=="Rain"]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
df["EST"].nunique()
# Out:
# 31

# %%
ds = df.drop(df.columns[0], axis=1)

# %%
ds = df.drop("Events", axis=1)

# %%
ds
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df["EST"][df["Events"]=="Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df[["EST"]&df["Events"]=="Rain"]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11248\4083534780.py:1: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   df[["EST"]&df["Events"]=="Rain"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Program Files\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)    360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# ...

# %%
df[ (df["Temperature"]>40) & (df["Events"] == "Rain") ]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %% [markdown]
# ## DATA STRUCTURES

# %% [markdown]
# ## Series

# %%
lst=[10,20,30,40]
d= pd.Series(lst)
d
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
a=pd.Series(lst,index=["a1","a2","a3","a4"],name="A")

# %%
a
# Out:
# a1    10
# a2    20
# a3    30
# a4    40
# Name: A, dtype: int64

# %%
print(d.loc[0:2])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
f=pd.Series(lst,dtype="float64")

# %%
f
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
d1={"sub1":"Java","sub2":"Python","sub3":"datascience","sub4":"AI/ML","sub5":"Maths"}

# %%
d1.items()
# Out:
# dict_items([('sub1', 'Java'), ('sub2', 'Python'), ('sub3', 'datascience'), ('sub4', 'AI/ML'), ('sub5', 'Maths')])

# %%
d1.values()
# Out:
# dict_values(['Java', 'Python', 'datascience', 'AI/ML', 'Maths'])

# %%
d1["sub5"]
# Out:
# 'Maths'

# %% [markdown]
# ## Dataframe

# %%
lst=[["Sagar",20],["Shahabas",21],["Nithin",22],["Sachin",23],["Pradul",24]]

# %%
df=pd.DataFrame(lst)

# %%
df
# Out:
#           0   1
# 0     Sagar  20
# 1  Shahabas  21
# 2    Nithin  22
# 3    Sachin  23
# 4    Pradul  24

# %%
df=pd.DataFrame(lst,columns=["Name","Age"])

# %%
df
# Out:
#        Name  Age
# 0     Sagar   20
# 1  Shahabas   21
# 2    Nithin   22
# 3    Sachin   23
# 4    Pradul   24

# %%
df.iloc[1:]
# Out:
#        Name  Age
# 1  Shahabas   21
# 2    Nithin   22
# 3    Sachin   23
# 4    Pradul   24

# %%
df.loc[1:]
# Out:
#        Name  Age
# 1  Shahabas   21
# 2    Nithin   22
# 3    Sachin   23
# 4    Pradul   24

# %%
df["salary"]=[1000,2000,3000,4000,5000]

# %%
df
# Out:
#        Name  Age  salary
# 0     Sagar   20    1000
# 1  Shahabas   21    2000
# 2    Nithin   22    3000
# 3    Sachin   23    4000
# 4    Pradul   24    5000

# %%
dicdata={"names":["SASI","SUGU","RAJU"],"subject":["maths","English","Malayalam"]}

# %%
df=pd.DataFrame(dicdata,index=[1,2,"a"])

# %%
df
# Out:
#   names    subject
# 1  SASI      maths
# 2  SUGU    English
# a  RAJU  Malayalam

# %%
d1={"totmark":[100,110,120,130],"ExtMarks":[80,75,65,90]}
df=pd.DataFrame(d1,index=[1,2,3,4])
df
# Out:
#    totmark  ExtMarks
# 1      100        80
# 2      110        75
# 3      120        65
# 4      130        90

# %%
df.iloc[3:,:]
# Out:
#    totmark  ExtMarks
# 4      130        90

# %%
df["c3"]=df["totmark"]+df["ExtMarks"]

# %%
df
# Out:
#    totmark  ExtMarks   c3
# 1      100        80  180
# 2      110        75  185
# 3      120        65  185
# 4      130        90  220

# %%
df["roll_no"]=range(1,5)

# %%
df
# Out:
#    totmark  ExtMarks   c3  roll_no
# 1      100        80  180        1
# 2      110        75  185        2
# 3      120        65  185        3
# 4      130        90  220        4

# %%
## Change column order
df=df[["roll_no","c3","totmark","ExtMarks"]]

# %%
df
# Out:
#    roll_no   c3  totmark  ExtMarks
# 1        1  180      100        80
# 2        2  185      110        75
# 3        3  185      120        65
# 4        4  220      130        90

# %%
df.sort_values(["ExtMarks"],ascending=False)
# Out:
#    roll_no   c3  totmark  ExtMarks
# 4        4  220      130        90
# 1        1  180      100        80
# 2        2  185      110        75
# 3        3  185      120        65

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...
